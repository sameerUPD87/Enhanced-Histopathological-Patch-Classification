# %%
import imageio
import numpy as np
import cv2
from matplotlib import pyplot as plt
from PIL import Image



for i in range (10,100):
    img=cv2.imread("competition_part1/Benign/" +"b0"+str(i)+".tif", 1)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    Io = 240 # Transmitted light intensity, Normalizing factor for image intensities
    alpha = 1  #As recommend in the paper. tolerance for the pseudo-min and pseudo-max (default: 1)
    beta = 0.15 #As recommended in the paper. OD threshold for transparent pixels (default: 0.15)


######## Step 1: Convert RGB to OD ###################
## reference H&E OD matrix.
#Can be updated if you know the best values for your image. 
#Otherwise use the following default values. 
#Read the above referenced papers on this topic. 
    HERef = np.array([[0.5626, 0.2159],
                  [0.7201, 0.8012],
                  [0.4062, 0.5581]])
### reference maximum stain concentrations for H&E
    maxCRef = np.array([1.9705, 1.0308])


# extract the height, width and num of channels of image
    h, w, c = img.shape

# reshape image to multiple rows and 3 columns.
#Num of rows depends on the image size (wxh)
    img = img.reshape((-1,3))

# calculate optical density
# OD = −log10(I)  
#OD = -np.log10(img+0.004)  #Use this when reading images with skimage
#Adding 0.004 just to avoid log of zero. 

    OD = -np.log10((img.astype(np.float)+1)/Io) #Use this for opencv imread
    ODhat = OD[~np.any(OD < beta, axis=1)] #Returns an array where OD values are above beta

    eigvals, eigvecs = np.linalg.eigh(np.cov(ODhat.T))    
    That = ODhat.dot(eigvecs[:,1:3]) 
    phi = np.arctan2(That[:,1],That[:,0])
    minPhi = np.percentile(phi, alpha)
    maxPhi = np.percentile(phi, 100-alpha)
    vMin = eigvecs[:,1:3].dot(np.array([(np.cos(minPhi), np.sin(minPhi))]).T)
    vMax = eigvecs[:,1:3].dot(np.array([(np.cos(maxPhi), np.sin(maxPhi))]).T)
    if vMin[0] > vMax[0]:    
        HE = np.array((vMin[:,0], vMax[:,0])).T
    else:
        HE = np.array((vMax[:,0], vMin[:,0])).T
    Y = np.reshape(OD, (-1, 3)).T
    C = np.linalg.lstsq(HE,Y, rcond=None)[0]
    maxC = np.array([np.percentile(C[0,:], 99), np.percentile(C[1,:],99)])
    tmp = np.divide(maxC,maxCRef)
    C2 = np.divide(C,tmp[:, np.newaxis])
    Inorm = np.multiply(Io, np.exp(-HERef.dot(C2)))
    Inorm[Inorm>255] = 254
    Inorm = np.reshape(Inorm.T, (h, w, 3)).astype(np.uint8)  
    H = np.multiply(Io, np.exp(np.expand_dims(-HERef[:,0], axis=1).dot(np.expand_dims(C2[0,:], axis=0))))
    H[H>255] = 254
    H = np.reshape(H.T, (h, w, 3)).astype(np.uint8)
    E = np.multiply(Io, np.exp(np.expand_dims(-HERef[:,1], axis=1).dot(np.expand_dims(C2[1,:], axis=0))))
    E[E>255] = 254
    E = np.reshape(E.T, (h, w, 3)).astype(np.uint8)
    imageio.imwrite("Normalized/Benign/" +"b0"+str(i)+".tif", Inorm)
    print("Normalization complete "+"b0"+str(i)+".tif")
# Out:
# C:\Users\samee\AppData\Local\Temp\ipykernel_6756\1950858496.py:48: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   OD = -np.log10((img.astype(np.float)+1)/Io) #Use this for opencv imread
# Normalization complete b010.tif
# Normalization complete b011.tif
# Normalization complete b012.tif
# Normalization complete b013.tif
# Normalization complete b014.tif
# Normalization complete b015.tif
# Normalization complete b016.tif
# Normalization complete b017.tif
# Normalization complete b018.tif
# Normalization complete b019.tif
# Normalization complete b020.tif
# Normalization complete b021.tif
# Normalization complete b022.tif
# Normalization complete b023.tif
# Normalization complete b024.tif
# Normalization complete b025.tif
# Normalization complete b026.tif
# Normalization complete b027.tif
# Normalization complete b028.tif
# Normalization complete b029.tif
# Normalization complete b030.tif
# Normalization complete b031.tif
# Normalization complete b032.tif
# Normalization complete b033.tif
# Normalization complete b034.tif
# Normalization complete b035.tif
# Normalization complete b036.tif
# Normalization complete b037.tif
# Normalization complete b038.tif
# Normalization complete b039.tif
# Normalization complete b040.tif
# Normalization complete b041.tif
# Normalization complete b042.tif
# Normalization complete b043.tif
# Normalization complete b044.tif
# Normalization complete b045.tif
# Normalization complete b046.tif
# Normalization complete b047.tif
# Normalization complete b048.tif
# Normalization complete b049.tif
# Normalization complete b050.tif
# Normalization complete b051.tif
# Normalization complete b052.tif
# Normalization complete b053.tif
# Normalization complete b054.tif
# Normalization complete b055.tif
# Normalization complete b056.tif
# Normalization complete b057.tif
# Normalization complete b058.tif
# Normalization complete b059.tif
# Normalization complete b060.tif
# Normalization complete b061.tif
# Normalization complete b062.tif
# Normalization complete b063.tif
# Normalization complete b064.tif
# Normalization complete b065.tif
# Normalization complete b066.tif
# Normalization complete b067.tif
# Normalization complete b068.tif
# Normalization complete b069.tif
# Normalization complete b070.tif
# Normalization complete b071.tif
# Normalization complete b072.tif
# Normalization complete b073.tif
# Normalization complete b074.tif
# Normalization complete b075.tif
# Normalization complete b076.tif
# Normalization complete b077.tif
# Normalization complete b078.tif
# Normalization complete b079.tif
# Normalization complete b080.tif
# Normalization complete b081.tif
# Normalization complete b082.tif
# Normalization complete b083.tif
# Normalization complete b084.tif
# Normalization complete b085.tif
# Normalization complete b086.tif
# Normalization complete b087.tif
# Normalization complete b088.tif
# Normalization complete b089.tif
# Normalization complete b090.tif
# Normalization complete b091.tif
# Normalization complete b092.tif
# Normalization complete b093.tif
# Normalization complete b094.tif
# Normalization complete b095.tif
# Normalization complete b096.tif
# Normalization complete b097.tif
# Normalization complete b098.tif
# Normalization complete b099.tif

# %%
for i in range (1,10):
    img=cv2.imread("competition_part1/Benign/" +"b00"+str(i)+".tif", 1)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    Io = 240 # Transmitted light intensity, Normalizing factor for image intensities
    alpha = 1  #As recommend in the paper. tolerance for the pseudo-min and pseudo-max (default: 1)
    beta = 0.15 #As recommended in the paper. OD threshold for transparent pixels (default: 0.15)


######## Step 1: Convert RGB to OD ###################
## reference H&E OD matrix.
#Can be updated if you know the best values for your image. 
#Otherwise use the following default values. 
#Read the above referenced papers on this topic. 
    HERef = np.array([[0.5626, 0.2159],
                  [0.7201, 0.8012],
                  [0.4062, 0.5581]])
### reference maximum stain concentrations for H&E
    maxCRef = np.array([1.9705, 1.0308])


# extract the height, width and num of channels of image
    h, w, c = img.shape

# reshape image to multiple rows and 3 columns.
#Num of rows depends on the image size (wxh)
    img = img.reshape((-1,3))

# calculate optical density
# OD = −log10(I)  
#OD = -np.log10(img+0.004)  #Use this when reading images with skimage
#Adding 0.004 just to avoid log of zero. 

    OD = -np.log10((img.astype(np.float)+1)/Io) #Use this for opencv imread
    ODhat = OD[~np.any(OD < beta, axis=1)] #Returns an array where OD values are above beta

    eigvals, eigvecs = np.linalg.eigh(np.cov(ODhat.T))    
    That = ODhat.dot(eigvecs[:,1:3]) 
    phi = np.arctan2(That[:,1],That[:,0])
    minPhi = np.percentile(phi, alpha)
    maxPhi = np.percentile(phi, 100-alpha)
    vMin = eigvecs[:,1:3].dot(np.array([(np.cos(minPhi), np.sin(minPhi))]).T)
    vMax = eigvecs[:,1:3].dot(np.array([(np.cos(maxPhi), np.sin(maxPhi))]).T)
    if vMin[0] > vMax[0]:    
        HE = np.array((vMin[:,0], vMax[:,0])).T
    else:
        HE = np.array((vMax[:,0], vMin[:,0])).T
    Y = np.reshape(OD, (-1, 3)).T
    C = np.linalg.lstsq(HE,Y, rcond=None)[0]
    maxC = np.array([np.percentile(C[0,:], 99), np.percentile(C[1,:],99)])
    tmp = np.divide(maxC,maxCRef)
    C2 = np.divide(C,tmp[:, np.newaxis])
    Inorm = np.multiply(Io, np.exp(-HERef.dot(C2)))
    Inorm[Inorm>255] = 254
    Inorm = np.reshape(Inorm.T, (h, w, 3)).astype(np.uint8)  
    H = np.multiply(Io, np.exp(np.expand_dims(-HERef[:,0], axis=1).dot(np.expand_dims(C2[0,:], axis=0))))
    H[H>255] = 254
    H = np.reshape(H.T, (h, w, 3)).astype(np.uint8)
    E = np.multiply(Io, np.exp(np.expand_dims(-HERef[:,1], axis=1).dot(np.expand_dims(C2[1,:], axis=0))))
    E[E>255] = 254
    E = np.reshape(E.T, (h, w, 3)).astype(np.uint8)
    imageio.imwrite("Normalized/Benign/" +"b00"+str(i)+".tif", Inorm)
    print("Normalization complete "+"b00"+str(i)+".tif")
# Out:
# C:\Users\samee\AppData\Local\Temp\ipykernel_6756\2377451977.py:34: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   OD = -np.log10((img.astype(np.float)+1)/Io) #Use this for opencv imread
# Normalization complete b001.tif
# Normalization complete b002.tif
# Normalization complete b003.tif
# Normalization complete b004.tif
# Normalization complete b005.tif
# Normalization complete b006.tif
# Normalization complete b007.tif
# Normalization complete b008.tif
# Normalization complete b009.tif

# %%
############### INPUT RGB IMAGE #######################
#Using opencv to read images may bemore robust compared to using skimage
#but need to remember to convert BGR to RGB.
#Also, convert to float later on and normalize to between 0 and 1.

#Image downloaded from:
#https://pbs.twimg.com/media/C1MkrgQWQAASbdz.jpg

for i in range (95,100):
    img=cv2.imread("competition_part1/Normal/" +"n0"+str(i)+".tif", 1)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    Io = 240 # Transmitted light intensity, Normalizing factor for image intensities
    alpha = 1  #As recommend in the paper. tolerance for the pseudo-min and pseudo-max (default: 1)
    beta = 0.15 #As recommended in the paper. OD threshold for transparent pixels (default: 0.15)


######## Step 1: Convert RGB to OD ###################
## reference H&E OD matrix.
#Can be updated if you know the best values for your image. 
#Otherwise use the following default values. 
#Read the above referenced papers on this topic. 
    HERef = np.array([[0.5626, 0.2159],
                  [0.7201, 0.8012],
                  [0.4062, 0.5581]])
### reference maximum stain concentrations for H&E
    maxCRef = np.array([1.9705, 1.0308])


# extract the height, width and num of channels of image
    h, w, c = img.shape

# reshape image to multiple rows and 3 columns.
#Num of rows depends on the image size (wxh)
    img = img.reshape((-1,3))

# calculate optical density
# OD = −log10(I)  
#OD = -np.log10(img+0.004)  #Use this when reading images with skimage
#Adding 0.004 just to avoid log of zero. 

    OD = -np.log10((img.astype(np.float)+1)/Io) #Use this for opencv imread
    ODhat = OD[~np.any(OD < beta, axis=1)] #Returns an array where OD values are above beta

    eigvals, eigvecs = np.linalg.eigh(np.cov(ODhat.T))    
    That = ODhat.dot(eigvecs[:,1:3]) 
    phi = np.arctan2(That[:,1],That[:,0])
    minPhi = np.percentile(phi, alpha)
    maxPhi = np.percentile(phi, 100-alpha)
    vMin = eigvecs[:,1:3].dot(np.array([(np.cos(minPhi), np.sin(minPhi))]).T)
    vMax = eigvecs[:,1:3].dot(np.array([(np.cos(maxPhi), np.sin(maxPhi))]).T)
    if vMin[0] > vMax[0]:    
        HE = np.array((vMin[:,0], vMax[:,0])).T
    else:
        HE = np.array((vMax[:,0], vMin[:,0])).T
    Y = np.reshape(OD, (-1, 3)).T
    C = np.linalg.lstsq(HE,Y, rcond=None)[0]
    maxC = np.array([np.percentile(C[0,:], 99), np.percentile(C[1,:],99)])
    tmp = np.divide(maxC,maxCRef)
    C2 = np.divide(C,tmp[:, np.newaxis])
    Inorm = np.multiply(Io, np.exp(-HERef.dot(C2)))
    Inorm[Inorm>255] = 254
    Inorm = np.reshape(Inorm.T, (h, w, 3)).astype(np.uint8)  
    H = np.multiply(Io, np.exp(np.expand_dims(-HERef[:,0], axis=1).dot(np.expand_dims(C2[0,:], axis=0))))
    H[H>255] = 254
    H = np.reshape(H.T, (h, w, 3)).astype(np.uint8)
    E = np.multiply(Io, np.exp(np.expand_dims(-HERef[:,1], axis=1).dot(np.expand_dims(C2[1,:], axis=0))))
    E[E>255] = 254
    E = np.reshape(E.T, (h, w, 3)).astype(np.uint8)
    imageio.imwrite("Normalized/Normal/" +"n0"+str(i)+".tif", Inorm)
    print("Normalization complete "+"n0"+str(i)+".tif")
# Out:
# C:\Users\samee\AppData\Local\Temp\ipykernel_6756\4260138095.py:42: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   OD = -np.log10((img.astype(np.float)+1)/Io) #Use this for opencv imread
# Normalization complete n095.tif
# Normalization complete n096.tif
# Normalization complete n097.tif
# Normalization complete n098.tif
# Normalization complete n099.tif

# %%
############### INPUT RGB IMAGE #######################
#Using opencv to read images may bemore robust compared to using skimage
#but need to remember to convert BGR to RGB.
#Also, convert to float later on and normalize to between 0 and 1.

#Image downloaded from:
#https://pbs.twimg.com/media/C1MkrgQWQAASbdz.jpg

for i in range (1,10):
    img=cv2.imread("competition_part1/Normal/" +"n00"+str(i)+".tif", 1)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    Io = 240 # Transmitted light intensity, Normalizing factor for image intensities
    alpha = 1  #As recommend in the paper. tolerance for the pseudo-min and pseudo-max (default: 1)
    beta = 0.15 #As recommended in the paper. OD threshold for transparent pixels (default: 0.15)


######## Step 1: Convert RGB to OD ###################
## reference H&E OD matrix.
#Can be updated if you know the best values for your image. 
#Otherwise use the following default values. 
#Read the above referenced papers on this topic. 
    HERef = np.array([[0.5626, 0.2159],
                  [0.7201, 0.8012],
                  [0.4062, 0.5581]])
### reference maximum stain concentrations for H&E
    maxCRef = np.array([1.9705, 1.0308])


# extract the height, width and num of channels of image
    h, w, c = img.shape

# reshape image to multiple rows and 3 columns.
#Num of rows depends on the image size (wxh)
    img = img.reshape((-1,3))

# calculate optical density
# OD = −log10(I)  
#OD = -np.log10(img+0.004)  #Use this when reading images with skimage
#Adding 0.004 just to avoid log of zero. 

    OD = -np.log10((img.astype(np.float)+1)/Io) #Use this for opencv imread
    ODhat = OD[~np.any(OD < beta, axis=1)] #Returns an array where OD values are above beta

    eigvals, eigvecs = np.linalg.eigh(np.cov(ODhat.T))    
    That = ODhat.dot(eigvecs[:,1:3]) 
    phi = np.arctan2(That[:,1],That[:,0])
    minPhi = np.percentile(phi, alpha)
    maxPhi = np.percentile(phi, 100-alpha)
    vMin = eigvecs[:,1:3].dot(np.array([(np.cos(minPhi), np.sin(minPhi))]).T)
    vMax = eigvecs[:,1:3].dot(np.array([(np.cos(maxPhi), np.sin(maxPhi))]).T)
    if vMin[0] > vMax[0]:    
        HE = np.array((vMin[:,0], vMax[:,0])).T
    else:
        HE = np.array((vMax[:,0], vMin[:,0])).T
    Y = np.reshape(OD, (-1, 3)).T
    C = np.linalg.lstsq(HE,Y, rcond=None)[0]
    maxC = np.array([np.percentile(C[0,:], 99), np.percentile(C[1,:],99)])
    tmp = np.divide(maxC,maxCRef)
    C2 = np.divide(C,tmp[:, np.newaxis])
    Inorm = np.multiply(Io, np.exp(-HERef.dot(C2)))
    Inorm[Inorm>255] = 254
    Inorm = np.reshape(Inorm.T, (h, w, 3)).astype(np.uint8)  
    H = np.multiply(Io, np.exp(np.expand_dims(-HERef[:,0], axis=1).dot(np.expand_dims(C2[0,:], axis=0))))
    H[H>255] = 254
    H = np.reshape(H.T, (h, w, 3)).astype(np.uint8)
    E = np.multiply(Io, np.exp(np.expand_dims(-HERef[:,1], axis=1).dot(np.expand_dims(C2[1,:], axis=0))))
    E[E>255] = 254
    E = np.reshape(E.T, (h, w, 3)).astype(np.uint8)
    imageio.imwrite("Normalized/Normal/" +"n00"+str(i)+".tif", Inorm)
    print("Normalization complete "+"n00"+str(i)+".tif")
# Out:
# C:\Users\samee\AppData\Local\Temp\ipykernel_6756\3042780551.py:42: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   OD = -np.log10((img.astype(np.float)+1)/Io) #Use this for opencv imread
# Normalization complete n001.tif
# Normalization complete n002.tif
# Normalization complete n003.tif
# Normalization complete n004.tif
# Normalization complete n005.tif
# Normalization complete n006.tif
# Normalization complete n007.tif
# Normalization complete n008.tif
# Normalization complete n009.tif

# %%
for i in range (97,100):
    img=cv2.imread("competition_part1/Invasive/" +"iv0"+str(i)+".tif", 1)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    Io = 240 # Transmitted light intensity, Normalizing factor for image intensities
    alpha = 1  #As recommend in the paper. tolerance for the pseudo-min and pseudo-max (default: 1)
    beta = 0.15 #As recommended in the paper. OD threshold for transparent pixels (default: 0.15)


######## Step 1: Convert RGB to OD ###################
## reference H&E OD matrix.
#Can be updated if you know the best values for your image. 
#Otherwise use the following default values. 
#Read the above referenced papers on this topic. 
    HERef = np.array([[0.5626, 0.2159],
                  [0.7201, 0.8012],
                  [0.4062, 0.5581]])
### reference maximum stain concentrations for H&E
    maxCRef = np.array([1.9705, 1.0308])


# extract the height, width and num of channels of image
    h, w, c = img.shape

# reshape image to multiple rows and 3 columns.
#Num of rows depends on the image size (wxh)
    img = img.reshape((-1,3))

# calculate optical density
# OD = −log10(I)  
#OD = -np.log10(img+0.004)  #Use this when reading images with skimage
#Adding 0.004 just to avoid log of zero. 

    OD = -np.log10((img.astype(np.float)+1)/Io) #Use this for opencv imread
    ODhat = OD[~np.any(OD < beta, axis=1)] #Returns an array where OD values are above beta

    eigvals, eigvecs = np.linalg.eigh(np.cov(ODhat.T))    
    That = ODhat.dot(eigvecs[:,1:3]) 
    phi = np.arctan2(That[:,1],That[:,0])
    minPhi = np.percentile(phi, alpha)
    maxPhi = np.percentile(phi, 100-alpha)
    vMin = eigvecs[:,1:3].dot(np.array([(np.cos(minPhi), np.sin(minPhi))]).T)
    vMax = eigvecs[:,1:3].dot(np.array([(np.cos(maxPhi), np.sin(maxPhi))]).T)
    if vMin[0] > vMax[0]:    
        HE = np.array((vMin[:,0], vMax[:,0])).T
    else:
        HE = np.array((vMax[:,0], vMin[:,0])).T
    Y = np.reshape(OD, (-1, 3)).T
    C = np.linalg.lstsq(HE,Y, rcond=None)[0]
    maxC = np.array([np.percentile(C[0,:], 99), np.percentile(C[1,:],99)])
    tmp = np.divide(maxC,maxCRef)
    C2 = np.divide(C,tmp[:, np.newaxis])
    Inorm = np.multiply(Io, np.exp(-HERef.dot(C2)))
    Inorm[Inorm>255] = 254
    Inorm = np.reshape(Inorm.T, (h, w, 3)).astype(np.uint8)  
    H = np.multiply(Io, np.exp(np.expand_dims(-HERef[:,0], axis=1).dot(np.expand_dims(C2[0,:], axis=0))))
    H[H>255] = 254
    H = np.reshape(H.T, (h, w, 3)).astype(np.uint8)
    E = np.multiply(Io, np.exp(np.expand_dims(-HERef[:,1], axis=1).dot(np.expand_dims(C2[1,:], axis=0))))
    E[E>255] = 254
    E = np.reshape(E.T, (h, w, 3)).astype(np.uint8)
    imageio.imwrite("Normalized/Invasive/" +"iv0"+str(i)+".tif", Inorm)
    print("Normalization complete "+"iv0"+str(i)+".tif")
# Out:
# C:\Users\samee\AppData\Local\Temp\ipykernel_6756\3980557393.py:34: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   OD = -np.log10((img.astype(np.float)+1)/Io) #Use this for opencv imread
# Normalization complete iv097.tif
# Normalization complete iv098.tif
# Normalization complete iv099.tif

# %%
for i in range (5,10):
    img=cv2.imread("competition_part1/Invasive/" +"iv00"+str(i)+".tif", 1)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    Io = 240 # Transmitted light intensity, Normalizing factor for image intensities
    alpha = 1  #As recommend in the paper. tolerance for the pseudo-min and pseudo-max (default: 1)
    beta = 0.15 #As recommended in the paper. OD threshold for transparent pixels (default: 0.15)


######## Step 1: Convert RGB to OD ###################
## reference H&E OD matrix.
#Can be updated if you know the best values for your image. 
#Otherwise use the following default values. 
#Read the above referenced papers on this topic. 
    HERef = np.array([[0.5626, 0.2159],
                  [0.7201, 0.8012],
                  [0.4062, 0.5581]])
### reference maximum stain concentrations for H&E
    maxCRef = np.array([1.9705, 1.0308])


# extract the height, width and num of channels of image
    h, w, c = img.shape

# reshape image to multiple rows and 3 columns.
#Num of rows depends on the image size (wxh)
    img = img.reshape((-1,3))

# calculate optical density
# OD = −log10(I)  
#OD = -np.log10(img+0.004)  #Use this when reading images with skimage
#Adding 0.004 just to avoid log of zero. 

    OD = -np.log10((img.astype(np.float)+1)/Io) #Use this for opencv imread
    ODhat = OD[~np.any(OD < beta, axis=1)] #Returns an array where OD values are above beta

    eigvals, eigvecs = np.linalg.eigh(np.cov(ODhat.T))    
    That = ODhat.dot(eigvecs[:,1:3]) 
    phi = np.arctan2(That[:,1],That[:,0])
    minPhi = np.percentile(phi, alpha)
    maxPhi = np.percentile(phi, 100-alpha)
    vMin = eigvecs[:,1:3].dot(np.array([(np.cos(minPhi), np.sin(minPhi))]).T)
    vMax = eigvecs[:,1:3].dot(np.array([(np.cos(maxPhi), np.sin(maxPhi))]).T)
    if vMin[0] > vMax[0]:    
        HE = np.array((vMin[:,0], vMax[:,0])).T
    else:
        HE = np.array((vMax[:,0], vMin[:,0])).T
    Y = np.reshape(OD, (-1, 3)).T
    C = np.linalg.lstsq(HE,Y, rcond=None)[0]
    maxC = np.array([np.percentile(C[0,:], 99), np.percentile(C[1,:],99)])
    tmp = np.divide(maxC,maxCRef)
    C2 = np.divide(C,tmp[:, np.newaxis])
    Inorm = np.multiply(Io, np.exp(-HERef.dot(C2)))
    Inorm[Inorm>255] = 254
    Inorm = np.reshape(Inorm.T, (h, w, 3)).astype(np.uint8)  
    H = np.multiply(Io, np.exp(np.expand_dims(-HERef[:,0], axis=1).dot(np.expand_dims(C2[0,:], axis=0))))
    H[H>255] = 254
    H = np.reshape(H.T, (h, w, 3)).astype(np.uint8)
    E = np.multiply(Io, np.exp(np.expand_dims(-HERef[:,1], axis=1).dot(np.expand_dims(C2[1,:], axis=0))))
    E[E>255] = 254
    E = np.reshape(E.T, (h, w, 3)).astype(np.uint8)
    imageio.imwrite("Normalized/Invasive/" +"iv00"+str(i)+".tif", Inorm)
    print("Normalization complete "+"iv00"+str(i)+".tif")
# Out:
# C:\Users\samee\AppData\Local\Temp\ipykernel_6756\447229444.py:34: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   OD = -np.log10((img.astype(np.float)+1)/Io) #Use this for opencv imread
# Normalization complete iv005.tif
# Normalization complete iv006.tif
# Normalization complete iv007.tif
# Normalization complete iv008.tif
# C:\Users\samee\AppData\Local\Temp\ipykernel_6756\447229444.py:37: RuntimeWarning: Degrees of freedom <= 0 for slice
#   eigvals, eigvecs = np.linalg.eigh(np.cov(ODhat.T))
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[25], line 37
#      34 OD = -np.log10((img.astype(np.float)+1)/Io) #Use this for opencv imread
#      35 ODhat = OD[~np.any(OD < beta, axis=1)] #Returns an array where OD values are above beta
# ---> 37 eigvals, eigvecs = np.linalg.eigh(np.cov(ODhat.T))
#      38 That = ODhat.dot(eigvecs[:,1:3])
#      39 phi = np.arctan2(That[:,1],That[:,0])
#
# File <__array_function__ internals>:180, in eigh(*args, **kwargs)
#
# File c:\Users\samee\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\linalg\linalg.py:1465, in eigh(a, UPLO)
#    1462     gufunc = _umath_linalg.eigh_up
#    1464 signature = 'D->dD' if isComplexType(t) else 'd->dd'
# -> 1465 w, vt = gufunc(a, signature=signature, extobj=extobj)
#    1466 w = w.astype(_realType(result_t), copy=False)
#    1467 vt = vt.astype(result_t, copy=False)
#
# File c:\Users\samee\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\linalg\linalg.py:95, in _raise_linalgerror_eigenvalues_nonconvergence(err, flag)
#      94 def _raise_linalgerror_eigenvalues_nonconvergence(err, flag):
# ---> 95     raise LinAlgError("Eigenvalues did not converge")
#
# LinAlgError: Eigenvalues did not converge
