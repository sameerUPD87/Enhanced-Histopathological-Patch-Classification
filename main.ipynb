# %%
import tensorflow as tf
import keras

import numpy as np
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Add, Dense,Dropout,Concatenate, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, GlobalAveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from tensorflow.keras.models import Model, load_model     # load_model is used to load the saved model
from tensorflow.keras.initializers import glorot_uniform  # it initialises the weights according to some distribution
from tensorflow.keras.optimizers import *
from matplotlib import pyplot as plt
from numpy import array
from matplotlib.pyplot import imshow
import tensorflow.keras.backend as K
import json
K.set_image_data_format('channels_last')
K.set_learning_phase(1)   
from tensorflow.keras.preprocessing.image import ImageDataGenerator    # ImageDataGenerator is used for handling bunches of images. It reads the images from folders and also labels them like as 0 for benign, 1 for insitu, 2 for invasive, 3 for normal
bn='bn_layer_'
conv='conv_layer_'
fc= 'fc_layer_'
k=32      # here k = no of channels at each layer
# Out:
# c:\Users\samee\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(

# %%
def bottleneck_composite(l,layer):   # everytime we call this function we create two layers
    # bottleneck layer
    X=l
    if type(l) is list:
        if(len(l)==1):
            X=l[0]
        else:
            X=Concatenate(axis=-1)(l)   # for channel-wise concatenation like if we have two 20x20 images to concatenate then by doing axis=-1 we want the result to be (20, 20, 2) and not (20,40)

    X = BatchNormalization(axis = 3, name = bn + str(layer))(X)
    X = Activation('relu')(X)
    X = Conv2D(4*k, (1, 1), strides = (1, 1),padding='same', name = conv + str(layer), kernel_initializer = glorot_uniform(seed=0))(X)  # to limit each layer input channel size to 4*k
    X = Dropout(0.8)(X)
    # Composite layer
    layer=layer+1
    X = BatchNormalization(axis = 3, name = bn +  str(layer))(X)
    X = Activation('relu')(X)
    X = Conv2D(k, (3, 3), strides = (1, 1),padding='same', name = conv +  str(layer), kernel_initializer = glorot_uniform(seed=0))(X)
    X = Dropout(0.8)(X)
    return X

# %%
layer=0    
def denseNet(classes=4,input_shape=(224,224,3)):
    X_input = Input(input_shape)   # X_input is a 4-D tensor (None, 224, 224, 3) where None would be replaced by batch size.
    layer=0
    layer=layer+1
    X = ZeroPadding2D((3, 3))(X_input)  # ZeroPadding2D is a function of the form ZeroPadding2D(( , ))(X) which pads onto the given array X
    X = BatchNormalization(axis = 3, name = bn + str(layer))(X)   # axis=3 indicates we batchnormalise channel-wise by doing (x-mean)/sd or something similar
    X = Activation('relu')(X)
    X = Conv2D(2*k, (7, 7), strides = (2, 2), name = conv + str(layer), kernel_initializer = glorot_uniform(seed=0))(X)  # 2*k is the no of filters/kernels, 7x7 is the kernel/filter size and seed=0 ensures consistency in results 
    X = Dropout(0.8)(X)    # 80% dropout
    print(X.shape)
    X = ZeroPadding2D((1, 1))(X)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)
    print(X.shape)

    #Dense Block = 1
    layer=layer+1
    X=bottleneck_composite(X,layer)
    l=[]
    l.append(X)
    for i in range(0,5):
        layer=layer+2         # we increment layer by 2 because each time we bottleneck_composite() we created two layers
        X=bottleneck_composite(l,layer)
        l.append(X)
    print(X.shape)

    # Transition layer = 1   
    layer=layer+2
    X = BatchNormalization(axis = 3, name = bn +  str(layer))(X)
    X = Activation('relu')(X)
    X = Conv2D(k, (1, 1), strides = (1, 1),padding ='same', name = conv +  str(layer), kernel_initializer = glorot_uniform(seed=0))(X)
    X = Dropout(0.8)(X)
    X = AveragePooling2D((2, 2), strides=(2, 2))(X)  
    print(X.shape)
    
    #Dense Block = 2
    layer=layer+1
    X=bottleneck_composite(X,layer)
    l=[]
    l.append(X)
    for i in range(0,11):
        layer=layer+2
        X=bottleneck_composite(l,layer)
        l.append(X)
    
    print(X.shape)

    # Transition layer = 2
    layer=layer+2
    X = BatchNormalization(axis = 3, name = bn +  str(layer))(X)
    X = Activation('relu')(X)
    X = Conv2D(k, (1, 1), strides = (1, 1),padding ='same', name = conv +  str(layer), kernel_initializer = glorot_uniform(seed=0))(X)
    X = Dropout(0.8)(X)
    X = AveragePooling2D((2, 2), strides=(2, 2))(X)  
    print(X.shape)

    #Dense Block = 3
    layer=layer+1
    X=bottleneck_composite(X,layer)
    l=[]
    l.append(X)
    for i in range(0,23):
        layer=layer+2
        X=bottleneck_composite(l,layer)
        l.append(X)
    print(X.shape)

    # Transition layer = 3
    layer=layer+2
    X = BatchNormalization(axis = 3, name = bn +  str(layer))(X)
    X = Activation('relu')(X)
    X = Conv2D(k, (1, 1), strides = (1, 1),padding ='same', name = conv +  str(layer), kernel_initializer = glorot_uniform(seed=0))(X)
    X = Dropout(0.8)(X)
    X = AveragePooling2D((2, 2), strides=(2, 2))(X)  
    print(X.shape)

    #Dense Block = 4
    layer=layer+1
    X=bottleneck_composite(X,layer)
    l=[]
    l.append(X)
    for i in range(0,15):
        layer=layer+2
        X=bottleneck_composite(l,layer)
        l.append(X)
    print(X.shape)
    layer=layer+2
    print(X.shape)

    X=  GlobalAveragePooling2D()(X)  # it works for each channel so if we have 32 channels we have 32 outputs
    print(X.shape)
   
    X = Dense(classes, activation='softmax', name=  fc  +  str(layer), kernel_initializer = glorot_uniform(seed=0))(X)  # output layer
    print(X.shape)
    model = Model(inputs = X_input, outputs = X, name="DenseNet121")   # this line builds the entire architecture pipeline
    
    return model

# %%
adam=Adam(learning_rate=0.001)   # we start with a random learning rate
model = denseNet(classes = 4,input_shape = (224,224,3))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])    
#model.summary()
train_datagen = ImageDataGenerator( rescale=1./255)    
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen=ImageDataGenerator(rescale=1./255)
# Out:
# (None, 112, 112, 64)
# (None, 56, 56, 64)
# (None, 56, 56, 32)
# (None, 28, 28, 32)
# (None, 28, 28, 32)
# (None, 14, 14, 32)
# (None, 14, 14, 32)
# (None, 7, 7, 32)
# (None, 7, 7, 32)
# (None, 7, 7, 32)
# (None, 32)
# (None, 4)

# %%
pip install --use-deprecated=legacy-resolver tensorflow==2.5.0

# %%
model.summary()
# Out:
# Model: "DenseNet121"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  zero_padding2d (ZeroPaddin  (None, 230, 230, 3)          0         ['input_1[0][0]']
#  g2D)
#
#  bn_layer_1 (BatchNormaliza  (None, 230, 230, 3)          12        ['zero_padding2d[0][0]']
#  tion)
#
#  activation (Activation)     (None, 230, 230, 3)          0         ['bn_layer_1[0][0]']
#
#  conv_layer_1 (Conv2D)       (None, 112, 112, 64)         9472      ['activation[0][0]']
#
#  dropout (Dropout)           (None, 112, 112, 64)         0         ['conv_layer_1[0][0]']
#
#  zero_padding2d_1 (ZeroPadd  (None, 114, 114, 64)         0         ['dropout[0][0]']
#  ing2D)
#
#  max_pooling2d (MaxPooling2  (None, 56, 56, 64)           0         ['zero_padding2d_1[0][0]']
#  D)
#
#  bn_layer_2 (BatchNormaliza  (None, 56, 56, 64)           256       ['max_pooling2d[0][0]']
#  tion)
#
#  activation_1 (Activation)   (None, 56, 56, 64)           0         ['bn_layer_2[0][0]']
#
#  conv_layer_2 (Conv2D)       (None, 56, 56, 128)          8320      ['activation_1[0][0]']
#
#  dropout_1 (Dropout)         (None, 56, 56, 128)          0         ['conv_layer_2[0][0]']
#
#  bn_layer_3 (BatchNormaliza  (None, 56, 56, 128)          512       ['dropout_1[0][0]']
#  tion)
#
#  activation_2 (Activation)   (None, 56, 56, 128)          0         ['bn_layer_3[0][0]']
#
#  conv_layer_3 (Conv2D)       (None, 56, 56, 32)           36896     ['activation_2[0][0]']
#
#  dropout_2 (Dropout)         (None, 56, 56, 32)           0         ['conv_layer_3[0][0]']
#
#  bn_layer_4 (BatchNormaliza  (None, 56, 56, 32)           128       ['dropout_2[0][0]']
#  tion)
#
#  activation_3 (Activation)   (None, 56, 56, 32)           0         ['bn_layer_4[0][0]']
#
#  conv_layer_4 (Conv2D)       (None, 56, 56, 128)          4224      ['activation_3[0][0]']
#
#  dropout_3 (Dropout)         (None, 56, 56, 128)          0         ['conv_layer_4[0][0]']
#
#  bn_layer_5 (BatchNormaliza  (None, 56, 56, 128)          512       ['dropout_3[0][0]']
#  tion)
#
#  activation_4 (Activation)   (None, 56, 56, 128)          0         ['bn_layer_5[0][0]']
#
#  conv_layer_5 (Conv2D)       (None, 56, 56, 32)           36896     ['activation_4[0][0]']
#
#  dropout_4 (Dropout)         (None, 56, 56, 32)           0         ['conv_layer_5[0][0]']
#
#  concatenate (Concatenate)   (None, 56, 56, 64)           0         ['dropout_2[0][0]',
#                                                                      'dropout_4[0][0]']
#
#  bn_layer_6 (BatchNormaliza  (None, 56, 56, 64)           256       ['concatenate[0][0]']
#  tion)
#
#  activation_5 (Activation)   (None, 56, 56, 64)           0         ['bn_layer_6[0][0]']
#
#  conv_layer_6 (Conv2D)       (None, 56, 56, 128)          8320      ['activation_5[0][0]']
#
#  dropout_5 (Dropout)         (None, 56, 56, 128)          0         ['conv_layer_6[0][0]']
#
#  bn_layer_7 (BatchNormaliza  (None, 56, 56, 128)          512       ['dropout_5[0][0]']
#  tion)
#
#  activation_6 (Activation)   (None, 56, 56, 128)          0         ['bn_layer_7[0][0]']
#
#  conv_layer_7 (Conv2D)       (None, 56, 56, 32)           36896     ['activation_6[0][0]']
#
#  dropout_6 (Dropout)         (None, 56, 56, 32)           0         ['conv_layer_7[0][0]']
#
#  concatenate_1 (Concatenate  (None, 56, 56, 96)           0         ['dropout_2[0][0]',
#  )                                                                   'dropout_4[0][0]',
#                                                                      'dropout_6[0][0]']
#
#  bn_layer_8 (BatchNormaliza  (None, 56, 56, 96)           384       ['concatenate_1[0][0]']
#  tion)
#
#  activation_7 (Activation)   (None, 56, 56, 96)           0         ['bn_layer_8[0][0]']
#
#  conv_layer_8 (Conv2D)       (None, 56, 56, 128)          12416     ['activation_7[0][0]']
#
#  dropout_7 (Dropout)         (None, 56, 56, 128)          0         ['conv_layer_8[0][0]']
#
#  bn_layer_9 (BatchNormaliza  (None, 56, 56, 128)          512       ['dropout_7[0][0]']
#  tion)
#
#  activation_8 (Activation)   (None, 56, 56, 128)          0         ['bn_layer_9[0][0]']
#
#  conv_layer_9 (Conv2D)       (None, 56, 56, 32)           36896     ['activation_8[0][0]']
#
#  dropout_8 (Dropout)         (None, 56, 56, 32)           0         ['conv_layer_9[0][0]']
#
#  concatenate_2 (Concatenate  (None, 56, 56, 128)          0         ['dropout_2[0][0]',
#  )                                                                   'dropout_4[0][0]',
#                                                                      'dropout_6[0][0]',
#                                                                      'dropout_8[0][0]']
#
#  bn_layer_10 (BatchNormaliz  (None, 56, 56, 128)          512       ['concatenate_2[0][0]']
#  ation)
#
#  activation_9 (Activation)   (None, 56, 56, 128)          0         ['bn_layer_10[0][0]']
#
#  conv_layer_10 (Conv2D)      (None, 56, 56, 128)          16512     ['activation_9[0][0]']
#
#  dropout_9 (Dropout)         (None, 56, 56, 128)          0         ['conv_layer_10[0][0]']
#
#  bn_layer_11 (BatchNormaliz  (None, 56, 56, 128)          512       ['dropout_9[0][0]']
#  ation)
#
#  activation_10 (Activation)  (None, 56, 56, 128)          0         ['bn_layer_11[0][0]']
#
#  conv_layer_11 (Conv2D)      (None, 56, 56, 32)           36896     ['activation_10[0][0]']
#
#  dropout_10 (Dropout)        (None, 56, 56, 32)           0         ['conv_layer_11[0][0]']
#
#  concatenate_3 (Concatenate  (None, 56, 56, 160)          0         ['dropout_2[0][0]',
#  )                                                                   'dropout_4[0][0]',
#                                                                      'dropout_6[0][0]',
#                                                                      'dropout_8[0][0]',
#                                                                      'dropout_10[0][0]']
#
#  bn_layer_12 (BatchNormaliz  (None, 56, 56, 160)          640       ['concatenate_3[0][0]']
#  ation)
#
#  activation_11 (Activation)  (None, 56, 56, 160)          0         ['bn_layer_12[0][0]']
#
#  conv_layer_12 (Conv2D)      (None, 56, 56, 128)          20608     ['activation_11[0][0]']
#
#  dropout_11 (Dropout)        (None, 56, 56, 128)          0         ['conv_layer_12[0][0]']
#
#  bn_layer_13 (BatchNormaliz  (None, 56, 56, 128)          512       ['dropout_11[0][0]']
#  ation)
#
#  activation_12 (Activation)  (None, 56, 56, 128)          0         ['bn_layer_13[0][0]']
#
#  conv_layer_13 (Conv2D)      (None, 56, 56, 32)           36896     ['activation_12[0][0]']
#
#  dropout_12 (Dropout)        (None, 56, 56, 32)           0         ['conv_layer_13[0][0]']
#
#  bn_layer_14 (BatchNormaliz  (None, 56, 56, 32)           128       ['dropout_12[0][0]']
#  ation)
#
#  activation_13 (Activation)  (None, 56, 56, 32)           0         ['bn_layer_14[0][0]']
#
#  conv_layer_14 (Conv2D)      (None, 56, 56, 32)           1056      ['activation_13[0][0]']
#
#  dropout_13 (Dropout)        (None, 56, 56, 32)           0         ['conv_layer_14[0][0]']
#
#  average_pooling2d (Average  (None, 28, 28, 32)           0         ['dropout_13[0][0]']
#  Pooling2D)
#
#  bn_layer_15 (BatchNormaliz  (None, 28, 28, 32)           128       ['average_pooling2d[0][0]']
#  ation)
#
#  activation_14 (Activation)  (None, 28, 28, 32)           0         ['bn_layer_15[0][0]']
#
#  conv_layer_15 (Conv2D)      (None, 28, 28, 128)          4224      ['activation_14[0][0]']
#
#  dropout_14 (Dropout)        (None, 28, 28, 128)          0         ['conv_layer_15[0][0]']
#
#  bn_layer_16 (BatchNormaliz  (None, 28, 28, 128)          512       ['dropout_14[0][0]']
#  ation)
#
#  activation_15 (Activation)  (None, 28, 28, 128)          0         ['bn_layer_16[0][0]']
#
#  conv_layer_16 (Conv2D)      (None, 28, 28, 32)           36896     ['activation_15[0][0]']
#
#  dropout_15 (Dropout)        (None, 28, 28, 32)           0         ['conv_layer_16[0][0]']
#
#  bn_layer_17 (BatchNormaliz  (None, 28, 28, 32)           128       ['dropout_15[0][0]']
#  ation)
#
#  activation_16 (Activation)  (None, 28, 28, 32)           0         ['bn_layer_17[0][0]']
#
#  conv_layer_17 (Conv2D)      (None, 28, 28, 128)          4224      ['activation_16[0][0]']
#
#  dropout_16 (Dropout)        (None, 28, 28, 128)          0         ['conv_layer_17[0][0]']
#
#  bn_layer_18 (BatchNormaliz  (None, 28, 28, 128)          512       ['dropout_16[0][0]']
#  ation)
#
#  activation_17 (Activation)  (None, 28, 28, 128)          0         ['bn_layer_18[0][0]']
#
#  conv_layer_18 (Conv2D)      (None, 28, 28, 32)           36896     ['activation_17[0][0]']
#
#  dropout_17 (Dropout)        (None, 28, 28, 32)           0         ['conv_layer_18[0][0]']
#
#  concatenate_4 (Concatenate  (None, 28, 28, 64)           0         ['dropout_15[0][0]',
#  )                                                                   'dropout_17[0][0]']
#
#  bn_layer_19 (BatchNormaliz  (None, 28, 28, 64)           256       ['concatenate_4[0][0]']
#  ation)
#
#  activation_18 (Activation)  (None, 28, 28, 64)           0         ['bn_layer_19[0][0]']
#
#  conv_layer_19 (Conv2D)      (None, 28, 28, 128)          8320      ['activation_18[0][0]']
#
#  dropout_18 (Dropout)        (None, 28, 28, 128)          0         ['conv_layer_19[0][0]']
#
#  bn_layer_20 (BatchNormaliz  (None, 28, 28, 128)          512       ['dropout_18[0][0]']
#  ation)
#
#  activation_19 (Activation)  (None, 28, 28, 128)          0         ['bn_layer_20[0][0]']
#
#  conv_layer_20 (Conv2D)      (None, 28, 28, 32)           36896     ['activation_19[0][0]']
#
#  dropout_19 (Dropout)        (None, 28, 28, 32)           0         ['conv_layer_20[0][0]']
#
#  concatenate_5 (Concatenate  (None, 28, 28, 96)           0         ['dropout_15[0][0]',
#  )                                                                   'dropout_17[0][0]',
#                                                                      'dropout_19[0][0]']
#
#  bn_layer_21 (BatchNormaliz  (None, 28, 28, 96)           384       ['concatenate_5[0][0]']
#  ation)
#
#  activation_20 (Activation)  (None, 28, 28, 96)           0         ['bn_layer_21[0][0]']
#
#  conv_layer_21 (Conv2D)      (None, 28, 28, 128)          12416     ['activation_20[0][0]']
#
#  dropout_20 (Dropout)        (None, 28, 28, 128)          0         ['conv_layer_21[0][0]']
#
#  bn_layer_22 (BatchNormaliz  (None, 28, 28, 128)          512       ['dropout_20[0][0]']
#  ation)
#
#  activation_21 (Activation)  (None, 28, 28, 128)          0         ['bn_layer_22[0][0]']
#
#  conv_layer_22 (Conv2D)      (None, 28, 28, 32)           36896     ['activation_21[0][0]']
#
#  dropout_21 (Dropout)        (None, 28, 28, 32)           0         ['conv_layer_22[0][0]']
#
#  concatenate_6 (Concatenate  (None, 28, 28, 128)          0         ['dropout_15[0][0]',
#  )                                                                   'dropout_17[0][0]',
#                                                                      'dropout_19[0][0]',
#                                                                      'dropout_21[0][0]']
#
#  bn_layer_23 (BatchNormaliz  (None, 28, 28, 128)          512       ['concatenate_6[0][0]']
#  ation)
#
#  activation_22 (Activation)  (None, 28, 28, 128)          0         ['bn_layer_23[0][0]']
#
#  conv_layer_23 (Conv2D)      (None, 28, 28, 128)          16512     ['activation_22[0][0]']
#
#  dropout_22 (Dropout)        (None, 28, 28, 128)          0         ['conv_layer_23[0][0]']
#
#  bn_layer_24 (BatchNormaliz  (None, 28, 28, 128)          512       ['dropout_22[0][0]']
#  ation)
#
#  activation_23 (Activation)  (None, 28, 28, 128)          0         ['bn_layer_24[0][0]']
#
#  conv_layer_24 (Conv2D)      (None, 28, 28, 32)           36896     ['activation_23[0][0]']
#
#  dropout_23 (Dropout)        (None, 28, 28, 32)           0         ['conv_layer_24[0][0]']
#
#  concatenate_7 (Concatenate  (None, 28, 28, 160)          0         ['dropout_15[0][0]',
#  )                                                                   'dropout_17[0][0]',
#                                                                      'dropout_19[0][0]',
#                                                                      'dropout_21[0][0]',
#                                                                      'dropout_23[0][0]']
#
#  bn_layer_25 (BatchNormaliz  (None, 28, 28, 160)          640       ['concatenate_7[0][0]']
#  ation)
#
#  activation_24 (Activation)  (None, 28, 28, 160)          0         ['bn_layer_25[0][0]']
#
#  conv_layer_25 (Conv2D)      (None, 28, 28, 128)          20608     ['activation_24[0][0]']
#
#  dropout_24 (Dropout)        (None, 28, 28, 128)          0         ['conv_layer_25[0][0]']
#
#  bn_layer_26 (BatchNormaliz  (None, 28, 28, 128)          512       ['dropout_24[0][0]']
#  ation)
#
#  activation_25 (Activation)  (None, 28, 28, 128)          0         ['bn_layer_26[0][0]']
#
#  conv_layer_26 (Conv2D)      (None, 28, 28, 32)           36896     ['activation_25[0][0]']
#
#  dropout_25 (Dropout)        (None, 28, 28, 32)           0         ['conv_layer_26[0][0]']
#
#  concatenate_8 (Concatenate  (None, 28, 28, 192)          0         ['dropout_15[0][0]',
#  )                                                                   'dropout_17[0][0]',
#                                                                      'dropout_19[0][0]',
#                                                                      'dropout_21[0][0]',
#                                                                      'dropout_23[0][0]',
#                                                                      'dropout_25[0][0]']
#
#  bn_layer_27 (BatchNormaliz  (None, 28, 28, 192)          768       ['concatenate_8[0][0]']
#  ation)
#
#  activation_26 (Activation)  (None, 28, 28, 192)          0         ['bn_layer_27[0][0]']
#
#  conv_layer_27 (Conv2D)      (None, 28, 28, 128)          24704     ['activation_26[0][0]']
#
#  dropout_26 (Dropout)        (None, 28, 28, 128)          0         ['conv_layer_27[0][0]']
#
#  bn_layer_28 (BatchNormaliz  (None, 28, 28, 128)          512       ['dropout_26[0][0]']
#  ation)
#
#  activation_27 (Activation)  (None, 28, 28, 128)          0         ['bn_layer_28[0][0]']
#
#  conv_layer_28 (Conv2D)      (None, 28, 28, 32)           36896     ['activation_27[0][0]']
#
#  dropout_27 (Dropout)        (None, 28, 28, 32)           0         ['conv_layer_28[0][0]']
#
#  concatenate_9 (Concatenate  (None, 28, 28, 224)          0         ['dropout_15[0][0]',
#  )                                                                   'dropout_17[0][0]',
#                                                                      'dropout_19[0][0]',
#                                                                      'dropout_21[0][0]',
#                                                                      'dropout_23[0][0]',
#                                                                      'dropout_25[0][0]',
#                                                                      'dropout_27[0][0]']
#
#  bn_layer_29 (BatchNormaliz  (None, 28, 28, 224)          896       ['concatenate_9[0][0]']
#  ation)
#
#  activation_28 (Activation)  (None, 28, 28, 224)          0         ['bn_layer_29[0][0]']
#
#  conv_layer_29 (Conv2D)      (None, 28, 28, 128)          28800     ['activation_28[0][0]']
#
#  dropout_28 (Dropout)        (None, 28, 28, 128)          0         ['conv_layer_29[0][0]']
#
#  bn_layer_30 (BatchNormaliz  (None, 28, 28, 128)          512       ['dropout_28[0][0]']
#  ation)
#
#  activation_29 (Activation)  (None, 28, 28, 128)          0         ['bn_layer_30[0][0]']
#
#  conv_layer_30 (Conv2D)      (None, 28, 28, 32)           36896     ['activation_29[0][0]']
#
#  dropout_29 (Dropout)        (None, 28, 28, 32)           0         ['conv_layer_30[0][0]']
#
#  concatenate_10 (Concatenat  (None, 28, 28, 256)          0         ['dropout_15[0][0]',
#  e)                                                                  'dropout_17[0][0]',
#                                                                      'dropout_19[0][0]',
#                                                                      'dropout_21[0][0]',
#                                                                      'dropout_23[0][0]',
#                                                                      'dropout_25[0][0]',
#                                                                      'dropout_27[0][0]',
#                                                                      'dropout_29[0][0]']
#
#  bn_layer_31 (BatchNormaliz  (None, 28, 28, 256)          1024      ['concatenate_10[0][0]']
#  ation)
#
#  activation_30 (Activation)  (None, 28, 28, 256)          0         ['bn_layer_31[0][0]']
#
#  conv_layer_31 (Conv2D)      (None, 28, 28, 128)          32896     ['activation_30[0][0]']
#
#  dropout_30 (Dropout)        (None, 28, 28, 128)          0         ['conv_layer_31[0][0]']
#
#  bn_layer_32 (BatchNormaliz  (None, 28, 28, 128)          512       ['dropout_30[0][0]']
#  ation)
#
#  activation_31 (Activation)  (None, 28, 28, 128)          0         ['bn_layer_32[0][0]']
#
#  conv_layer_32 (Conv2D)      (None, 28, 28, 32)           36896     ['activation_31[0][0]']
#
#  dropout_31 (Dropout)        (None, 28, 28, 32)           0         ['conv_layer_32[0][0]']
#
#  concatenate_11 (Concatenat  (None, 28, 28, 288)          0         ['dropout_15[0][0]',
#  e)                                                                  'dropout_17[0][0]',
#                                                                      'dropout_19[0][0]',
#                                                                      'dropout_21[0][0]',
#                                                                      'dropout_23[0][0]',
#                                                                      'dropout_25[0][0]',
#                                                                      'dropout_27[0][0]',
#                                                                      'dropout_29[0][0]',
#                                                                      'dropout_31[0][0]']
#
#  bn_layer_33 (BatchNormaliz  (None, 28, 28, 288)          1152      ['concatenate_11[0][0]']
#  ation)
#
#  activation_32 (Activation)  (None, 28, 28, 288)          0         ['bn_layer_33[0][0]']
#
#  conv_layer_33 (Conv2D)      (None, 28, 28, 128)          36992     ['activation_32[0][0]']
#
#  dropout_32 (Dropout)        (None, 28, 28, 128)          0         ['conv_layer_33[0][0]']
#
#  bn_layer_34 (BatchNormaliz  (None, 28, 28, 128)          512       ['dropout_32[0][0]']
#  ation)
#
#  activation_33 (Activation)  (None, 28, 28, 128)          0         ['bn_layer_34[0][0]']
#
#  conv_layer_34 (Conv2D)      (None, 28, 28, 32)           36896     ['activation_33[0][0]']
#
#  dropout_33 (Dropout)        (None, 28, 28, 32)           0         ['conv_layer_34[0][0]']
#
#  concatenate_12 (Concatenat  (None, 28, 28, 320)          0         ['dropout_15[0][0]',
#  e)                                                                  'dropout_17[0][0]',
#                                                                      'dropout_19[0][0]',
#                                                                      'dropout_21[0][0]',
#                                                                      'dropout_23[0][0]',
#                                                                      'dropout_25[0][0]',
#                                                                      'dropout_27[0][0]',
#                                                                      'dropout_29[0][0]',
#                                                                      'dropout_31[0][0]',
#                                                                      'dropout_33[0][0]']
#
#  bn_layer_35 (BatchNormaliz  (None, 28, 28, 320)          1280      ['concatenate_12[0][0]']
#  ation)
#
#  activation_34 (Activation)  (None, 28, 28, 320)          0         ['bn_layer_35[0][0]']
#
#  conv_layer_35 (Conv2D)      (None, 28, 28, 128)          41088     ['activation_34[0][0]']
#
#  dropout_34 (Dropout)        (None, 28, 28, 128)          0         ['conv_layer_35[0][0]']
#
#  bn_layer_36 (BatchNormaliz  (None, 28, 28, 128)          512       ['dropout_34[0][0]']
#  ation)
#
#  activation_35 (Activation)  (None, 28, 28, 128)          0         ['bn_layer_36[0][0]']
#
#  conv_layer_36 (Conv2D)      (None, 28, 28, 32)           36896     ['activation_35[0][0]']
#
#  dropout_35 (Dropout)        (None, 28, 28, 32)           0         ['conv_layer_36[0][0]']
#
#  concatenate_13 (Concatenat  (None, 28, 28, 352)          0         ['dropout_15[0][0]',
#  e)                                                                  'dropout_17[0][0]',
#                                                                      'dropout_19[0][0]',
#                                                                      'dropout_21[0][0]',
#                                                                      'dropout_23[0][0]',
#                                                                      'dropout_25[0][0]',
#                                                                      'dropout_27[0][0]',
#                                                                      'dropout_29[0][0]',
#                                                                      'dropout_31[0][0]',
#                                                                      'dropout_33[0][0]',
#                                                                      'dropout_35[0][0]']
#
#  bn_layer_37 (BatchNormaliz  (None, 28, 28, 352)          1408      ['concatenate_13[0][0]']
#  ation)
#
#  activation_36 (Activation)  (None, 28, 28, 352)          0         ['bn_layer_37[0][0]']
#
#  conv_layer_37 (Conv2D)      (None, 28, 28, 128)          45184     ['activation_36[0][0]']
#
#  dropout_36 (Dropout)        (None, 28, 28, 128)          0         ['conv_layer_37[0][0]']
#
#  bn_layer_38 (BatchNormaliz  (None, 28, 28, 128)          512       ['dropout_36[0][0]']
#  ation)
#
#  activation_37 (Activation)  (None, 28, 28, 128)          0         ['bn_layer_38[0][0]']
#
#  conv_layer_38 (Conv2D)      (None, 28, 28, 32)           36896     ['activation_37[0][0]']
#
#  dropout_37 (Dropout)        (None, 28, 28, 32)           0         ['conv_layer_38[0][0]']
#
#  bn_layer_39 (BatchNormaliz  (None, 28, 28, 32)           128       ['dropout_37[0][0]']
#  ation)
#
#  activation_38 (Activation)  (None, 28, 28, 32)           0         ['bn_layer_39[0][0]']
#
#  conv_layer_39 (Conv2D)      (None, 28, 28, 32)           1056      ['activation_38[0][0]']
#
#  dropout_38 (Dropout)        (None, 28, 28, 32)           0         ['conv_layer_39[0][0]']
#
#  average_pooling2d_1 (Avera  (None, 14, 14, 32)           0         ['dropout_38[0][0]']
#  gePooling2D)
#
#  bn_layer_40 (BatchNormaliz  (None, 14, 14, 32)           128       ['average_pooling2d_1[0][0]']
#  ation)
#
#  activation_39 (Activation)  (None, 14, 14, 32)           0         ['bn_layer_40[0][0]']
#
#  conv_layer_40 (Conv2D)      (None, 14, 14, 128)          4224      ['activation_39[0][0]']
#
#  dropout_39 (Dropout)        (None, 14, 14, 128)          0         ['conv_layer_40[0][0]']
#
#  bn_layer_41 (BatchNormaliz  (None, 14, 14, 128)          512       ['dropout_39[0][0]']
#  ation)
#
#  activation_40 (Activation)  (None, 14, 14, 128)          0         ['bn_layer_41[0][0]']
#
#  conv_layer_41 (Conv2D)      (None, 14, 14, 32)           36896     ['activation_40[0][0]']
#
#  dropout_40 (Dropout)        (None, 14, 14, 32)           0         ['conv_layer_41[0][0]']
#
#  bn_layer_42 (BatchNormaliz  (None, 14, 14, 32)           128       ['dropout_40[0][0]']
#  ation)
# ...
#  conv_layer_111 (Conv2D)     (None, 7, 7, 128)            45184     ['activation_110[0][0]']
#
#  dropout_110 (Dropout)       (None, 7, 7, 128)            0         ['conv_layer_111[0][0]']
#
#  bn_layer_112 (BatchNormali  (None, 7, 7, 128)            512       ['dropout_110[0][0]']
#  zation)
#
#  activation_111 (Activation  (None, 7, 7, 128)            0         ['bn_layer_112[0][0]']
#  )
#
#  conv_layer_112 (Conv2D)     (None, 7, 7, 32)             36896     ['activation_111[0][0]']
#
#  dropout_111 (Dropout)       (None, 7, 7, 32)             0         ['conv_layer_112[0][0]']
#
#  concatenate_46 (Concatenat  (None, 7, 7, 384)            0         ['dropout_89[0][0]',
#  e)                                                                  'dropout_91[0][0]',
#                                                                      'dropout_93[0][0]',
#                                                                      'dropout_95[0][0]',
#                                                                      'dropout_97[0][0]',
#                                                                      'dropout_99[0][0]',
#                                                                      'dropout_101[0][0]',
#                                                                      'dropout_103[0][0]',
#                                                                      'dropout_105[0][0]',
#                                                                      'dropout_107[0][0]',
#                                                                      'dropout_109[0][0]',
#                                                                      'dropout_111[0][0]']
#
#  bn_layer_113 (BatchNormali  (None, 7, 7, 384)            1536      ['concatenate_46[0][0]']
#  zation)
#
#  activation_112 (Activation  (None, 7, 7, 384)            0         ['bn_layer_113[0][0]']
#  )
#
#  conv_layer_113 (Conv2D)     (None, 7, 7, 128)            49280     ['activation_112[0][0]']
#
#  dropout_112 (Dropout)       (None, 7, 7, 128)            0         ['conv_layer_113[0][0]']
#
#  bn_layer_114 (BatchNormali  (None, 7, 7, 128)            512       ['dropout_112[0][0]']
#  zation)
#
#  activation_113 (Activation  (None, 7, 7, 128)            0         ['bn_layer_114[0][0]']
#  )
#
#  conv_layer_114 (Conv2D)     (None, 7, 7, 32)             36896     ['activation_113[0][0]']
#
#  dropout_113 (Dropout)       (None, 7, 7, 32)             0         ['conv_layer_114[0][0]']
#
#  concatenate_47 (Concatenat  (None, 7, 7, 416)            0         ['dropout_89[0][0]',
#  e)                                                                  'dropout_91[0][0]',
#                                                                      'dropout_93[0][0]',
#                                                                      'dropout_95[0][0]',
#                                                                      'dropout_97[0][0]',
#                                                                      'dropout_99[0][0]',
#                                                                      'dropout_101[0][0]',
#                                                                      'dropout_103[0][0]',
#                                                                      'dropout_105[0][0]',
#                                                                      'dropout_107[0][0]',
#                                                                      'dropout_109[0][0]',
#                                                                      'dropout_111[0][0]',
#                                                                      'dropout_113[0][0]']
#
#  bn_layer_115 (BatchNormali  (None, 7, 7, 416)            1664      ['concatenate_47[0][0]']
#  zation)
#
#  activation_114 (Activation  (None, 7, 7, 416)            0         ['bn_layer_115[0][0]']
#  )
#
#  conv_layer_115 (Conv2D)     (None, 7, 7, 128)            53376     ['activation_114[0][0]']
#
#  dropout_114 (Dropout)       (None, 7, 7, 128)            0         ['conv_layer_115[0][0]']
#
#  bn_layer_116 (BatchNormali  (None, 7, 7, 128)            512       ['dropout_114[0][0]']
#  zation)
#
#  activation_115 (Activation  (None, 7, 7, 128)            0         ['bn_layer_116[0][0]']
#  )
#
#  conv_layer_116 (Conv2D)     (None, 7, 7, 32)             36896     ['activation_115[0][0]']
#
#  dropout_115 (Dropout)       (None, 7, 7, 32)             0         ['conv_layer_116[0][0]']
#
#  concatenate_48 (Concatenat  (None, 7, 7, 448)            0         ['dropout_89[0][0]',
#  e)                                                                  'dropout_91[0][0]',
#                                                                      'dropout_93[0][0]',
#                                                                      'dropout_95[0][0]',
#                                                                      'dropout_97[0][0]',
#                                                                      'dropout_99[0][0]',
#                                                                      'dropout_101[0][0]',
#                                                                      'dropout_103[0][0]',
#                                                                      'dropout_105[0][0]',
#                                                                      'dropout_107[0][0]',
#                                                                      'dropout_109[0][0]',
#                                                                      'dropout_111[0][0]',
#                                                                      'dropout_113[0][0]',
#                                                                      'dropout_115[0][0]']
#
#  bn_layer_117 (BatchNormali  (None, 7, 7, 448)            1792      ['concatenate_48[0][0]']
#  zation)
#
#  activation_116 (Activation  (None, 7, 7, 448)            0         ['bn_layer_117[0][0]']
#  )
#
#  conv_layer_117 (Conv2D)     (None, 7, 7, 128)            57472     ['activation_116[0][0]']
#
#  dropout_116 (Dropout)       (None, 7, 7, 128)            0         ['conv_layer_117[0][0]']
#
#  bn_layer_118 (BatchNormali  (None, 7, 7, 128)            512       ['dropout_116[0][0]']
#  zation)
#
#  activation_117 (Activation  (None, 7, 7, 128)            0         ['bn_layer_118[0][0]']
#  )
#
#  conv_layer_118 (Conv2D)     (None, 7, 7, 32)             36896     ['activation_117[0][0]']
#
#  dropout_117 (Dropout)       (None, 7, 7, 32)             0         ['conv_layer_118[0][0]']
#
#  concatenate_49 (Concatenat  (None, 7, 7, 480)            0         ['dropout_89[0][0]',
#  e)                                                                  'dropout_91[0][0]',
#                                                                      'dropout_93[0][0]',
#                                                                      'dropout_95[0][0]',
#                                                                      'dropout_97[0][0]',
#                                                                      'dropout_99[0][0]',
#                                                                      'dropout_101[0][0]',
#                                                                      'dropout_103[0][0]',
#                                                                      'dropout_105[0][0]',
#                                                                      'dropout_107[0][0]',
#                                                                      'dropout_109[0][0]',
#                                                                      'dropout_111[0][0]',
#                                                                      'dropout_113[0][0]',
#                                                                      'dropout_115[0][0]',
#                                                                      'dropout_117[0][0]']
#
#  bn_layer_119 (BatchNormali  (None, 7, 7, 480)            1920      ['concatenate_49[0][0]']
#  zation)
#
#  activation_118 (Activation  (None, 7, 7, 480)            0         ['bn_layer_119[0][0]']
#  )
#
#  conv_layer_119 (Conv2D)     (None, 7, 7, 128)            61568     ['activation_118[0][0]']
#
#  dropout_118 (Dropout)       (None, 7, 7, 128)            0         ['conv_layer_119[0][0]']
#
#  bn_layer_120 (BatchNormali  (None, 7, 7, 128)            512       ['dropout_118[0][0]']
#  zation)
#
#  activation_119 (Activation  (None, 7, 7, 128)            0         ['bn_layer_120[0][0]']
#  )
#
#  conv_layer_120 (Conv2D)     (None, 7, 7, 32)             36896     ['activation_119[0][0]']
#
#  dropout_119 (Dropout)       (None, 7, 7, 32)             0         ['conv_layer_120[0][0]']
#
#  global_average_pooling2d (  (None, 32)                   0         ['dropout_119[0][0]']
#  GlobalAveragePooling2D)
#
#  fc_layer_121 (Dense)        (None, 4)                    132       ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 4226224 (16.12 MB)
# Trainable params: 4180330 (15.95 MB)
# Non-trainable params: 45894 (179.27 KB)
# __________________________________________________________________________________________________

# %%
 # we need to mention from which directory images will come from
train_generator = train_datagen.flow_from_directory(  
        'new/Train',
        target_size=(224,224),
        batch_size=32,
        class_mode='categorical')     
# categorical means one-hot encoded ytrue values i.e. it alphabetically classifies the different classes and gives them a unique number( 0 for benign, 1 for insitu, 2 for invasive, 3 for normal)

validation_generator = val_datagen.flow_from_directory(
        'new/Validation',
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical')
test_generator=test_datagen.flow_from_directory(
        'new/Test',
        target_size=(224,224), 
        batch_size=32,
        class_mode='categorical')

print(train_generator.class_indices) # print out the class names along with their unique nos.
print(test_generator.class_indices)
print(validation_generator.class_indices)
# Out:
# Found 68880 images belonging to 4 classes.
# Found 5600 images belonging to 4 classes.
# Found 5600 images belonging to 4 classes.
# {'Benign': 0, 'InSitu': 1, 'Invasive': 2, 'Normal': 3}
# {'Benign': 0, 'InSitu': 1, 'Invasive': 2, 'Normal': 3}
# {'Benign': 0, 'InSitu': 1, 'Invasive': 2, 'Normal': 3}

# %%
history=model.fit(train_generator, epochs =25,steps_per_epoch=2153,validation_data=validation_generator, validation_steps=175)  # steps_per_epoch = no of batches in the training set = 68880/32 = 2153
# Out:
# Epoch 1/25
# 2153/2153 [==============================] - 1918s 891ms/step - loss: 0.6007 - accuracy: 0.7692 - val_loss: 0.2817 - val_accuracy: 0.9407
# Epoch 2/25
# 2153/2153 [==============================] - 1894s 880ms/step - loss: 0.2564 - accuracy: 0.9171 - val_loss: 0.1545 - val_accuracy: 0.9414
# Epoch 3/25
# 2153/2153 [==============================] - 1895s 880ms/step - loss: 0.1600 - accuracy: 0.9484 - val_loss: 0.0718 - val_accuracy: 0.9786
# Epoch 4/25
# 2153/2153 [==============================] - 1895s 880ms/step - loss: 0.1129 - accuracy: 0.9635 - val_loss: 0.0765 - val_accuracy: 0.9711
# Epoch 5/25
# 2153/2153 [==============================] - 1896s 881ms/step - loss: 0.0870 - accuracy: 0.9728 - val_loss: 0.1333 - val_accuracy: 0.9587
# Epoch 6/25
# 2153/2153 [==============================] - 1896s 881ms/step - loss: 0.0595 - accuracy: 0.9809 - val_loss: 0.0774 - val_accuracy: 0.9705
# Epoch 7/25
# 2153/2153 [==============================] - 1896s 881ms/step - loss: 0.0579 - accuracy: 0.9817 - val_loss: 0.0387 - val_accuracy: 0.9879
# Epoch 8/25
# 2153/2153 [==============================] - 1896s 881ms/step - loss: 0.0415 - accuracy: 0.9873 - val_loss: 0.0325 - val_accuracy: 0.9902
# Epoch 9/25
# 2153/2153 [==============================] - 1897s 881ms/step - loss: 0.0384 - accuracy: 0.9885 - val_loss: 0.0681 - val_accuracy: 0.9827
# Epoch 10/25
# 2153/2153 [==============================] - 1896s 881ms/step - loss: 0.0380 - accuracy: 0.9887 - val_loss: 0.0235 - val_accuracy: 0.9932
# Epoch 11/25
# 2153/2153 [==============================] - 1898s 881ms/step - loss: 0.0315 - accuracy: 0.9907 - val_loss: 0.0269 - val_accuracy: 0.9907
# Epoch 12/25
# 2153/2153 [==============================] - 1898s 881ms/step - loss: 0.0264 - accuracy: 0.9919 - val_loss: 0.0426 - val_accuracy: 0.9862
# Epoch 13/25
# 2153/2153 [==============================] - 1897s 881ms/step - loss: 0.0235 - accuracy: 0.9926 - val_loss: 0.0253 - val_accuracy: 0.9929
# Epoch 14/25
# 2153/2153 [==============================] - 1897s 881ms/step - loss: 0.0240 - accuracy: 0.9931 - val_loss: 0.0263 - val_accuracy: 0.9918
# Epoch 15/25
# 2153/2153 [==============================] - 1896s 881ms/step - loss: 0.0199 - accuracy: 0.9938 - val_loss: 0.0125 - val_accuracy: 0.9961
# Epoch 16/25
# 2153/2153 [==============================] - 1897s 881ms/step - loss: 0.0187 - accuracy: 0.9947 - val_loss: 0.0190 - val_accuracy: 0.9948
# Epoch 17/25
# 2153/2153 [==============================] - 1897s 881ms/step - loss: 0.0156 - accuracy: 0.9955 - val_loss: 0.0530 - val_accuracy: 0.9827
# Epoch 18/25
# 2153/2153 [==============================] - 1898s 881ms/step - loss: 0.0154 - accuracy: 0.9957 - val_loss: 0.0258 - val_accuracy: 0.9907
# Epoch 19/25
# 2153/2153 [==============================] - 1897s 881ms/step - loss: 0.0154 - accuracy: 0.9952 - val_loss: 0.0388 - val_accuracy: 0.9925
# Epoch 20/25
# 2153/2153 [==============================] - 1897s 881ms/step - loss: 0.0177 - accuracy: 0.9949 - val_loss: 0.0805 - val_accuracy: 0.9686
# Epoch 21/25
# 2153/2153 [==============================] - 1896s 881ms/step - loss: 0.0115 - accuracy: 0.9966 - val_loss: 0.0132 - val_accuracy: 0.9959
# Epoch 22/25
# 2153/2153 [==============================] - 1896s 881ms/step - loss: 0.0131 - accuracy: 0.9964 - val_loss: 0.0156 - val_accuracy: 0.9961
# Epoch 23/25
# 2153/2153 [==============================] - 1897s 881ms/step - loss: 0.0133 - accuracy: 0.9960 - val_loss: 0.0147 - val_accuracy: 0.9950
# Epoch 24/25
# 2153/2153 [==============================] - 1897s 881ms/step - loss: 0.0101 - accuracy: 0.9970 - val_loss: 0.0127 - val_accuracy: 0.9952
# Epoch 25/25
# 2153/2153 [==============================] - 1897s 881ms/step - loss: 0.0113 - accuracy: 0.9967 - val_loss: 0.0160 - val_accuracy: 0.9957

# %%
# Evaluate the model on the test data
test_loss, test_accuracy = model.evaluate(test_generator)

# Print the overall test loss and accuracy
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# 88/88 [==============================] - 13s 146ms/step - loss: 0.7445 - accuracy: 0.9080
# Test Loss: 0.744450330668
# Test Accuracy: 0.90803571428
